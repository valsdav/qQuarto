# %%
import QuartoTrain
# Out:
# Using TensorFlow backend.
# Now we build the model
# We finish building the model
# Now we load weight
# Weight load successfully
# Epoch 100 	| State observe 	| Epsilon 0.1000 	| N.images    0 	| TP 0.00 	| TT 0.00 	|  Reward  -52 	| Q_sa  0.000 	| Q_sa_target  0.000 	| Loss    0.000
# Epoch 200 	| State observe 	| Epsilon 0.1000 	| N.images    0 	| TP 0.00 	| TT 0.00 	|  Reward  -35 	| Q_sa  0.000 	| Q_sa_target  0.000 	| Loss    0.000
# Epoch 300 	| State observe 	| Epsilon 0.1000 	| N.images    0 	| TP 0.00 	| TT 0.00 	|  Reward   -8 	| Q_sa  0.000 	| Q_sa_target  0.000 	| Loss    0.000
# Epoch 400 	| State observe 	| Epsilon 0.1000 	| N.images    0 	| TP 0.00 	| TT 0.00 	|  Reward  125 	| Q_sa  0.000 	| Q_sa_target  0.000 	| Loss    0.000
# Epoch 500 	| State observe 	| Epsilon 0.1000 	| N.images    0 	| TP 0.00 	| TT 0.00 	|  Reward -103 	| Q_sa  0.000 	| Q_sa_target  0.000 	| Loss    0.000
# ...
